# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("conversion_data.csv")
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
df.sample(10)
# Out:
#        ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 295   777905              936          115762  30-34      M        31
# 386   781327              936          116367  35-39      F        29
# 801  1121671             1178          144635  45-49      M        28
# 653  1121347             1178          144581  35-39      M        24
# 698  1121437             1178          144596  35-39      M        66
# 120   737130              936          109507  35-39      M        16
# 237   776623              936          115535  45-49      M        64
# 124   737644              936          109629  45-49      M        16
# 106   735220              936          108823  45-49      F        15
# 582  1121213             1178          144556  30-34      M        30
#
#      Impressions  Clicks      Spent  Total_Conversion  Approved_Conversion
# 295         3288       0   0.000000                 1                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   xyz_campaign_id      1143 non-null   int64
#  2   fb_campaign_id       1143 non-null   int64
#  3   age                  1143 non-null   object
#  4   gender               1143 non-null   object
#  5   interest             1143 non-null   int64
#  6   Impressions          1143 non-null   int64
#  7   Clicks               1143 non-null   int64
#  8   Spent                1143 non-null   float64
#  9   Total_Conversion     1143 non-null   int64
#  10  Approved_Conversion  1143 non-null   int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 98.4+ KB

# %%
df.describe()
# Out:
#               ad_id  xyz_campaign_id  fb_campaign_id     interest  \
# count  1.143000e+03      1143.000000     1143.000000  1143.000000
# mean   9.872611e+05      1067.382327   133783.989501    32.766404
# std    1.939928e+05       121.629393    20500.308622    26.952131
# min    7.087460e+05       916.000000   103916.000000     2.000000
# 25%    7.776325e+05       936.000000   115716.000000    16.000000
# 50%    1.121185e+06      1178.000000   144549.000000    25.000000
# 75%    1.121804e+06      1178.000000   144657.500000    31.000000
# max    1.314415e+06      1178.000000   179982.000000   114.000000
#
#         Impressions       Clicks        Spent  Total_Conversion  \
# count  1.143000e+03  1143.000000  1143.000000       1143.000000
# mean   1.867321e+05    33.390201    51.360656          2.855643
# std    3.127622e+05    56.892438    86.908418          4.483593
# min    8.700000e+01     0.000000     0.000000          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
df.loc[df['Total_Conversion']>df['Clicks']]
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 2      708771              916          103920  30-34      M        20
# 5      708820              916          103929  30-34      M        29
# 10     708979              916          103955  30-34      M        31
# 11     709023              916          103962  30-34      M         7
# ...       ...              ...             ...    ...    ...       ...
# 851   1121791             1178          144655  30-34      F        23
# 880   1121846             1178          144664  30-34      F        32
# 882   1121854             1178          144666  30-34      F        63
# 894   1121873             1178          144669  30-34      F         2
# 1056  1314308             1178          179875  30-34      M       112
#
#       Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# ...

# %%
df_cleaned = df.loc[df['Total_Conversion']<=df['Clicks']]
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 925 entries, 1 to 1142
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                925 non-null    int64
#  1   xyz_campaign_id      925 non-null    int64
#  2   fb_campaign_id       925 non-null    int64
#  3   age                  925 non-null    object
#  4   gender               925 non-null    object
#  5   interest             925 non-null    int64
#  6   Impressions          925 non-null    int64
#  7   Clicks               925 non-null    int64
#  8   Spent                925 non-null    float64
#  9   Total_Conversion     925 non-null    int64
#  10  Approved_Conversion  925 non-null    int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 86.7+ KB

# %%
df_cleaned.sample(10)
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 623   1121292             1178          144572  35-39      M        10
# 16     709115              916          103978  30-34      M        30
# 1086  1314350             1178          179917  45-49      M       109
# 1075  1314334             1178          179901  40-44      M       108
# 71     734582              936          108716  40-44      M        29
# 534   1121113             1178          144534  30-34      M        18
# 1065  1314321             1178          179888  35-39      M       110
# 891   1121867             1178          144668  30-34      F        65
# 938   1122004             1178          144691  35-39      F        63
# 792   1121660             1178          144633  45-49      M        26
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# 623        362296      39   67.770001                 7                    3
# ...

# %%
df_cleaned.to_csv("conversion_data_cleaned.csv", index=False)

# %%
df_cleaned.loc[df['Clicks']==0,'Spent']
# Out:
# 95     0.0
# 184    0.0
# 510    0.0
# Name: Spent, dtype: float64

# %%
df_cleaned['xyz_campaign_id'].value_counts()
# Out:
# 1178    608
# 936     284
# 916      33
# Name: xyz_campaign_id, dtype: int64

# %%
df_cleaned['interest'].value_counts()
# Out:
# 16     113
# 10      69
# 29      60
# 27      52
# 28      42
# 20      40
# 63      37
# 64      36
# 15      35
# 18      34
# 22      31
# 26      29
# 19      27
# 21      25
# 25      24
# 32      24
# 24      22
# 30      19
# 2       19
# 23      18
# 7       17
# 31      17
# 36      16
# 65      15
# 66      10
# 107      8
# 110      8
# 101      7
# 102      7
# 105      7
# 108      7
# 111      6
# 112      6
# 113      6
# 100      6
# 109      6
# 106      5
# 104      5
# 103      5
# 114      5
# Name: interest, dtype: int64

# %%
df_cleaned['age'].value_counts()
# Out:
# 30-34    296
# 45-49    231
# 35-39    212
# 40-44    186
# Name: age, dtype: int64

# %%
df_cleaned['gender'].value_counts()
# Out:
# M    463
# F    462
# Name: gender, dtype: int64

# %%
df_cleaned['ad_id'].nunique()
# Out:
# 925

# %%
df_cleaned.groupby('xyz_campaign_id')['fb_campaign_id'].nunique()
# Out:
# xyz_campaign_id
# 916      31
# 936     232
# 1178    274
# Name: fb_campaign_id, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
g=sns.heatmap(df_cleaned[["Impressions","Clicks","Spent","Total_Conversion","Approved_Conversion"]].corr(),annot=True ,fmt=".2f", cmap="coolwarm")

# %% [markdown]
# 关键指标：
# 广告花费Spent：与点击量clicks 和 展示量Impressions 有很强相关性；
# 付费人数Approved_Conversion： 与展示量Impressions 和 转化人数Total_Conversion 有强相关性；

# %%
df_cleaned['Conversion_Rate'] = df_cleaned['Total_Conversion']/df_cleaned['Clicks']
# Out:
# <ipython-input-44-8ab0cf01c448>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Conversion_Rate'] = df_cleaned['Total_Conversion']/df_cleaned['Clicks']
#               ad_id  xyz_campaign_id  fb_campaign_id    interest  \
# count  9.250000e+02       925.000000      925.000000  925.000000
# mean   1.024473e+06      1094.352432   137675.187027   34.261622
# std    1.888350e+05       115.962382    20315.062245   28.613272
# min    7.087490e+05       916.000000   103917.000000    2.000000
# 25%    7.804980e+05       936.000000   116218.000000   16.000000
# 50%    1.121381e+06      1178.000000   144587.000000   25.000000
# 75%    1.121904e+06      1178.000000   144674.000000   32.000000
# ...

# %%
df_cleaned.drop(['Conversion_Rate'],axis=1)
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 1      708749              916          103917  30-34      M        16
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# 6      708889              916          103940  30-34      M        15
# 7      708895              916          103941  30-34      M        16
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# ...

# %%
df_cleaned.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708749              916          103917  30-34      M        16
# 1  708815              916          103928  30-34      M        28
# 2  708818              916          103928  30-34      M        28
# 3  708889              916          103940  30-34      M        15
# 4  708895              916          103941  30-34      M        16
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0        17861       2   1.82                 2                    0
# 1         4259       1   1.25                 1                    0
# 2         4133       1   1.29                 1                    1
# 3        15615       3   4.77                 1                    0
# 4        10951       1   1.27                 1                    1
#
#    Conversion_Rate
# 0         1.000000
# 1         1.000000
# 2         1.000000
# 3         0.333333
# 4         1.000000

# %%
df_cleaned.index = range(df_cleaned.shape[0])

# %%
df_cleaned.interest.value_counts()
# Out:
# 16     113
# 10      69
# 29      60
# 27      52
# 28      42
# 20      40
# 63      37
# 64      36
# 15      35
# 18      34
# 22      31
# 26      29
# 19      27
# 21      25
# 25      24
# 32      24
# 24      22
# 30      19
# 2       19
# 23      18
# 7       17
# 31      17
# 36      16
# 65      15
# 66      10
# 107      8
# 110      8
# 101      7
# 102      7
# 105      7
# 108      7
# 111      6
# 112      6
# 113      6
# 100      6
# 109      6
# 106      5
# 104      5
# 103      5
# 114      5
# Name: interest, dtype: int64

# %%
df_cleaned[df_cleaned.Spent == 0]
# Out:
#       ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 95   735033              936          108792  35-39      F        36
# 184  747968              936          110962  35-39      F        21
# 510  951853              936          123736  30-34      F        20
#
#      Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 95           652       0    0.0                 0                    0
# 184          512       0    0.0                 0                    0
# 510          529       0    0.0                 0                    0
